# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dans ce notebook, nous allons introduire l'analyse des séries temporelles. Une série temporelle est une série dont l'index est le temps. Un exemple de série temporelle est par exemple, la température d'un pays sur une année, le prix du bitcoin ces 6 derniers mois. Ces valeurs diminuent ou augmentent en fonction du temps. Les analyser nous permet donc d'identifier les tendances, la saisonabilité et plus encore.

# %% [markdown]
# Pour ce projet, nous allons utiliser des données de consommation d'énergie electrique et également de production en énergie solaire et éolienne en Allemagne de 2006 à 2017

# %%
energy = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')

# %%
energy.shape
# Out:
# (4383, 5)

# %%
energy.sample(5)
# Out:
#             Date  Consumption     Wind    Solar  Wind+Solar
# 3376  2015-03-31   1517.41900  624.674   69.416     694.090
# 4283  2017-09-23   1191.10345   28.878  117.186     146.064
# 1142  2009-02-16   1467.76700      NaN      NaN         NaN
# 78    2006-03-20   1446.23800      NaN      NaN         NaN
# 2835  2013-10-06   1029.17100   14.973   38.165      53.138

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   object
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 171.3+ KB

# %%
energy['Date']
# Out:
# 0       2006-01-01
# 1       2006-01-02
# 2       2006-01-03
# 3       2006-01-04
# 4       2006-01-05
#            ...
# 4378    2017-12-27
# 4379    2017-12-28
# 4380    2017-12-29
# 4381    2017-12-30
# 4382    2017-12-31
# Name: Date, Length: 4383, dtype: object

# %%
energy['Date'] = pd.to_datetime(energy['Date'])

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %%
energy = energy.set_index('Date')

# %%
energy.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# Proportion de valeurs manquantes

# %%
energy.isnull().mean()
# Out:
# Consumption    0.000000
# Wind           0.333790
# Solar          0.500799
# Wind+Solar     0.501027
# dtype: float64

# %%
energy.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
energy.index[:5]
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
energy.index[:5].year
# Out:
# Index([2006, 2006, 2006, 2006, 2006], dtype='int32', name='Date')

# %%
energy.index[:5].month
# Out:
# Index([1, 1, 1, 1, 1], dtype='int32', name='Date')

# %%
energy.index[:5].day
# Out:
# Index([1, 2, 3, 4, 5], dtype='int32', name='Date')

# %%
energy.index[:5].day_name()
# Out:
# Index(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday'], dtype='object', name='Date')

# %% [markdown]
# Création de colonnes (features) relatives à la date :

# %%
energy['Year'] = energy.index.year

# %%
energy.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  Year
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  2006
# 2006-01-02     1380.521   NaN    NaN         NaN  2006
# 2006-01-03     1442.533   NaN    NaN         NaN  2006
# 2006-01-04     1457.217   NaN    NaN         NaN  2006
# 2006-01-05     1477.131   NaN    NaN         NaN  2006

# %%
energy.Year.value_counts()
# Out:
# Year
# 2008    366
# 2012    366
# 2016    366
# 2006    365
# 2007    365
# 2009    365
# 2010    365
# 2011    365
# 2013    365
# 2014    365
# 2015    365
# 2017    365
# Name: count, dtype: int64

# %%
energy['Month'] = energy.index.month
energy['day_name'] = energy.index.day_name()

# %%
energy.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  Year  Month   day_name
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  2006      1     Sunday
# 2006-01-02     1380.521   NaN    NaN         NaN  2006      1     Monday
# 2006-01-03     1442.533   NaN    NaN         NaN  2006      1    Tuesday
# 2006-01-04     1457.217   NaN    NaN         NaN  2006      1  Wednesday
# 2006-01-05     1477.131   NaN    NaN         NaN  2006      1   Thursday

# %%
energy['is_weekend'] = energy.day_name.isin(["Sunday", "Saturday"])

# %% [markdown]
# Quick tip  :

# %%
(energy.day_name == 'Saturday') &   (energy.day_name == 'Sunday')
# Out:
# Date
# 2006-01-01    False
# 2006-01-02    False
# 2006-01-03    False
# 2006-01-04    False
# 2006-01-05    False
#               ...
# 2017-12-27    False
# 2017-12-28    False
# 2017-12-29    False
# 2017-12-30    False
# 2017-12-31    False
# Name: day_name, Length: 4383, dtype: bool

# %%
energy
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month   day_name  \
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1     Sunday
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1     Monday
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1    Tuesday
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1  Wednesday
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1   Thursday
# ...                 ...      ...     ...         ...   ...    ...        ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12  Wednesday
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12   Thursday
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12     Friday
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12   Saturday
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12     Sunday
#
#             is_weekend
# Date
# 2006-01-01        True
# 2006-01-02       False
# 2006-01-03       False
# 2006-01-04       False
# 2006-01-05       False
# ...                ...
# 2017-12-27       False
# 2017-12-28       False
# 2017-12-29       False
# 2017-12-30        True
# 2017-12-31        True
#
# [4383 rows x 8 columns]

# %%
energy.Year.max()
# Out:
# 2017

# %%
energy.loc["2016-12-23": "2016-12-28"]
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month   day_name  \
# Date
# 2016-12-23     1415.811  395.296  16.111     411.407  2016     12     Friday
# 2016-12-24     1195.354  681.509  12.843     694.352  2016     12   Saturday
# 2016-12-25     1117.673  719.778   6.608     726.386  2016     12     Sunday
# 2016-12-26     1121.213  718.160  15.463     733.623  2016     12     Monday
# 2016-12-27     1289.324  640.895  23.448     664.343  2016     12    Tuesday
# 2016-12-28     1294.881  214.990  19.450     234.440  2016     12  Wednesday
#
#             is_weekend
# Date
# 2016-12-23       False
# 2016-12-24        True
# 2016-12-25        True
# 2016-12-26       False
# 2016-12-27       False
# 2016-12-28       False

# %% [markdown]
# ## Consommation en énergie au fil des années

# %%
sns.set_style("whitegrid")
energy['Consumption'].plot(linewidth=.5, figsize=(10, 8))
plt.show()

# %% [markdown]
# ## Quel est le jour avec le plus de consommation en global?

# %%
# Jour avec le plus de consommation
energy.groupby('day_name').sum()['Consumption'].sort_values()
# Out:
# day_name
# Sunday       691646.51735
# Saturday     751544.19949
# Monday       870006.24492
# Friday       873034.67157
# Thursday     889645.06681
# Tuesday      894101.79246
# Wednesday    897437.69479
# Name: Consumption, dtype: float64

# %%
groupday = energy.groupby('day_name').sum()['Consumption'].reset_index()
groupday
# Out:
#     day_name   Consumption
# 0     Friday  873034.67157
# 1     Monday  870006.24492
# 2   Saturday  751544.19949
# 3     Sunday  691646.51735
# 4   Thursday  889645.06681
# 5    Tuesday  894101.79246
# 6  Wednesday  897437.69479

# %%
order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sns.barplot(x = groupday['day_name'], y = groupday['Consumption'], order=order)
plt.show()

# %%
energy.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %% [markdown]
# ## Consommation par année

# %%
grid = sns.FacetGrid(energy, row="Year")
grid.map(plt.plot,'Consumption')

# %%
data = energy.loc['2016'].copy()

# %%
data
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month   day_name  \
# Date
# 2016-01-01     1060.366  107.209  18.563     125.772  2016      1     Friday
# 2016-01-02     1192.698  409.622   9.406     419.028  2016      1   Saturday
# 2016-01-03     1179.282  406.296  13.519     419.815  2016      1     Sunday
# 2016-01-04     1456.294  278.460  10.080     288.540  2016      1     Monday
# 2016-01-05     1506.737  206.468  12.549     219.017  2016      1    Tuesday
# ...                 ...      ...     ...         ...   ...    ...        ...
# 2016-12-27     1289.324  640.895  23.448     664.343  2016     12    Tuesday
# 2016-12-28     1294.881  214.990  19.450     234.440  2016     12  Wednesday
# 2016-12-29     1295.897  167.698  42.910     210.608  2016     12   Thursday
# 2016-12-30     1291.044  239.257  48.546     287.803  2016     12     Friday
# 2016-12-31     1212.568  315.063  34.580     349.643  2016     12   Saturday
#
#             is_weekend
# Date
# 2016-01-01       False
# 2016-01-02        True
# 2016-01-03        True
# 2016-01-04       False
# 2016-01-05       False
# ...                ...
# 2016-12-27       False
# 2016-12-28       False
# 2016-12-29       False
# 2016-12-30       False
# 2016-12-31        True
#
# [366 rows x 8 columns]

# %%
energy.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
data.index
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25',
#                '2016-12-26', '2016-12-27', '2016-12-28', '2016-12-29',
#                '2016-12-30', '2016-12-31'],
#               dtype='datetime64[ns]', name='Date', length=366, freq=None)

# %%
sns.scatterplot( x = data.index, y=data['Consumption'])
plt.xlim(data.index.min(), data.index.max())
# Out:
# (16801.0, 17166.0)

# %%
fig, axes = plt.subplots(figsize=(16, 10), nrows=3, ncols=1)

sns.scatterplot(data =data, x = data.index, y='Consumption', ax=axes[0])
axes[0].set_title('Consommation en energie en 2016')
axes[0].set_xlim(data.index.min(), data.index.max())
 
sns.scatterplot(data =data, x = data.index, y='Solar',ax=axes[1])
axes[1].set_title("Production d'energie solaire en 2016")
axes[1].set_xlim(data.index.min(), data.index.max())

sns.scatterplot(data =data, x = data.index, y='Wind',ax=axes[2])
axes[2].set_title("Production d'energie eolienne en 2016")
axes[2].set_xlim(data.index.min(), data.index.max())
fig.tight_layout(pad=2)

# %%
fig, ax = plt.subplots(figsize=(16, 10), nrows=1, ncols=1)
sns.lineplot(data =data, x = data.index, y='Consumption', ax=ax, legend='brief', label='consommation')

 
sns.lineplot(data =data, x = data.index, y='Solar',ax=ax, legend='brief', label='production solaire')


# sns.scatterplot(data =data_2016, x = data.index, y='Wind',ax=axes[2])
# axes[2].set_title("Production d'energie eolienne en 2016")
# fig.tight_layout(pad=2)
# Out:
# <Axes: xlabel='Date', ylabel='Consumption'>

# %%
energy.columns
# Out:
# Index(['Consumption', 'Wind', 'Solar', 'Wind+Solar', 'Year', 'Month',
#        'day_name', 'is_weekend'],
#       dtype='object')

# %% [markdown]
# ## Consommation par mois

# %%
sns.boxplot(data=energy, x="Month", y='Consumption')
# Out:
# <Axes: xlabel='Month', ylabel='Consumption'>

# %%
energy.columns
# Out:
# Index(['Consumption', 'Wind', 'Solar', 'Wind+Solar', 'Year', 'Month',
#        'day_name', 'is_weekend'],
#       dtype='object')

# %%
energy["day_name"].unique()
# Out:
# array(['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Saturday'], dtype=object)

# %%
g = sns.boxplot(data=energy, x="day_name", y='Consumption')
g.set_xticklabels(rotation=30, labels=energy["day_name"].unique())
plt.show()
# Out:
# C:\Users\ing\AppData\Local\Temp\ipykernel_8244\458185032.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(rotation=30, labels=energy["day_name"].unique())

# %% [markdown]
# ## Consommation en semaine vs Weekend

# %%
g = sns.boxplot(data=energy, x="is_weekend", y='Consumption')
g.set_xticklabels(rotation=30, labels=energy["is_weekend"].unique())
plt.show()
# Out:
# C:\Users\ing\AppData\Local\Temp\ipykernel_8244\3828166646.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(rotation=30, labels=energy["is_weekend"].unique())

# %% [markdown]
# ## Consommation en moyenne par mois

# %%
conso_par_mois = energy.drop(['Year',"Month", "is_weekend"], axis=1).resample('M').sum()
conso_par_mois
# Out:
#             Consumption       Wind     Solar  Wind+Solar  \
# Date
# 2006-01-31  45304.70400      0.000     0.000       0.000
# 2006-02-28  41078.99300      0.000     0.000       0.000
# 2006-03-31  43978.12400      0.000     0.000       0.000
# 2006-04-30  38251.76700      0.000     0.000       0.000
# 2006-05-31  38858.14300      0.000     0.000       0.000
# ...                 ...        ...       ...         ...
# 2017-08-31  40029.77368   5499.798  4602.808   10102.606
# 2017-09-30  40078.56092   6287.730  3079.291    9367.021
# 2017-10-31  42355.21893  12480.097  2130.557   14610.654
# 2017-11-30  44339.72455  10259.001   831.044   11090.045
# 2017-12-31  44511.10431  14725.436   494.171   15219.607
#
#                                                      day_name
# Date
# 2006-01-31  SundayMondayTuesdayWednesdayThursdayFridaySatu...
# 2006-02-28  WednesdayThursdayFridaySaturdaySundayMondayTue...
# 2006-03-31  WednesdayThursdayFridaySaturdaySundayMondayTue...
# 2006-04-30  SaturdaySundayMondayTuesdayWednesdayThursdayFr...
# 2006-05-31  MondayTuesdayWednesdayThursdayFridaySaturdaySu...
# ...                                                       ...
# 2017-08-31  TuesdayWednesdayThursdayFridaySaturdaySundayMo...
# 2017-09-30  FridaySaturdaySundayMondayTuesdayWednesdayThur...
# 2017-10-31  SundayMondayTuesdayWednesdayThursdayFridaySatu...
# 2017-11-30  WednesdayThursdayFridaySaturdaySundayMondayTue...
# 2017-12-31  FridaySaturdaySundayMondayTuesdayWednesdayThur...
#
# [144 rows x 5 columns]

# %% [markdown]
# ## Consommation par trimestre

# %%
 energy.drop(['Year',"Month", "is_weekend"], axis=1).resample('Q').sum()
# Out:
#              Consumption       Wind      Solar  Wind+Solar  \
# Date
# 2006-03-31  130361.82100      0.000      0.000       0.000
# 2006-06-30  114363.36000      0.000      0.000       0.000
# 2006-09-30  116664.13500      0.000      0.000       0.000
# 2006-12-31  127679.22000      0.000      0.000       0.000
